# %%
# pyspark packages
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType, BooleanType

#other needed packages
import re
import os

# Set JAVA_HOME for PySpark
os.environ['JAVA_HOME'] = '/opt/homebrew/opt/openjdk@17'

spark = SparkSession.builder \
    .appName("stock market preds") \
    .config("spark.driver.host", "127.0.0.1") \
    .getOrCreate()
spark.sparkContext.setLogLevel("ERROR")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/01/12 19:56:10 WARN Utils: Your hostname, Jeffreys-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 10.0.0.17 instead (on interface en0)
# 26/01/12 19:56:10 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/01/12 19:56:10 WARN Utils: Your hostname, Jeffreys-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 10.0.0.17 instead (on interface en0)
# 26/01/12 19:56:10 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/12 19:56:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/01/12 19:56:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# functions to import data, run SQL from file and save back to file
# function to import and clean columns
def import_csv_to_table(table_name, file, format_cols):

    #read source files
    df = spark.read.csv(file, header=True, quote="\"",
                        escape="\"", multiLine=True, inferSchema=True)

    #clean column names
    if format_cols:
        cols_formatted = [re.sub(r"[^a-zA-Z0-9\s]", "", col_name).lower().replace(" ", "_") for col_name in df.columns]
        df = df.toDF(*cols_formatted)

    # create SQL view
    df.createOrReplaceTempView(f"{table_name}")
    return df

#run a SQL step
def sql_step(file):
    with open(file, 'r', encoding='utf-8') as file:
        sql_text = file.read()
    results = spark.sql(sql_text)
    return results

#run SQL and view output inline
def run_sql(file, rowstoshow, print_sql):
    with open(file, 'r', encoding='utf-8') as file:
        sql_text = file.read()
    results = spark.sql(sql_text)
    if print_sql == True: print(sql_text)
    results.show(rowstoshow, truncate=False)

# export data frame to csv
def export_csv(df, output_dir, final_file_name):
    df.coalesce(1).write.csv(output_dir, header=True, mode="overwrite")
    for file in os.listdir(output_dir):
        if file.startswith("part-") and file.endswith(".csv"):
            part_file_path = os.path.join(output_dir, file)
            break
    if part_file_path:
        os.rename(part_file_path, os.path.join(output_dir, final_file_name))
        print(f"CSV saved as: {final_file_name}")
    else:
        print("Error: Part file not found.")

# %%
news = import_csv_to_table("news", "raw_data/news_data.csv", False)
stocks = import_csv_to_table("stocks", "raw_data/stock_data.csv", False)

# %%
news.show()
# Out:
# +--------+--------------------+--------------------+-----------------+-------------------+-------------------+--------------------+--------------------+--------+
# |      id|            headline|             summary|           author|         created_at|         updated_at|                 url|             symbols|  source|
# +--------+--------------------+--------------------+-----------------+-------------------+-------------------+--------------------+--------------------+--------+
# |49701666|Evercore ISI Grou...|                NULL|Benzinga Newsdesk|2026-01-05 10:50:55|2026-01-05 10:50:56|https://www.benzi...|                   A|benzinga|
# |49391324|Barclays Upgrades...|                NULL|Benzinga Newsdesk|2025-12-15 06:49:28|2025-12-15 06:49:29|https://www.benzi...|                   A|benzinga|
# |49342760|What's Driving th...|                    |Benzinga Insights|2025-12-11 11:00:38|2025-12-11 11:00:39|https://www.benzi...|                   A|benzinga|
# |49276887|Goldman Sachs Ini...|                NULL|Benzinga Newsdesk|2025-12-09 05:32:55|2025-12-09 05:32:56|https://www.benzi...|                   A|benzinga|
# |49190655|10 Health Care St...|                    |Benzinga Insights|2025-12-03 10:35:29|2025-12-03 10:35:29|https://www.benzi...|A,COR,IOVA,LLY,NK...|benzinga|
# |49161291|Morgan Stanley In...|                NULL|Benzinga Newsdesk|2025-12-02 08:02:49|2025-12-02 08:02:49|https://www.benzi...|                   A|benzinga|
# |49069188|Spotlight on Agil...|                    |Benzinga Insights|2025-11-25 13:02:46|2025-11-25 13:02:47|https://www.benzi...|                   A|benzinga|
# |49067586|Citigroup Maintai...|                NULL|Benzinga Newsdesk|2025-11-25 12:05:00|2025-11-25 12:05:01|https://www.benzi...|                   A|benzinga|
# |49065822|These Analysts Bo...|                    |       Avi Kapoor|2025-11-25 11:06:00|2025-11-25 11:06:00|https://www.benzi...|                   A|benzinga|
# |49065306|UBS Maintains Buy...|                NULL|Benzinga Newsdesk|2025-11-25 10:53:34|2025-11-25 10:53:35|https://www.benzi...|                   A|benzinga|
# |49059896|Wells Fargo Maint...|                NULL|Benzinga Newsdesk|2025-11-25 08:40:51|2025-11-25 08:40:52|https://www.benzi...|                   A|benzinga|
# |49058450|JP Morgan Maintai...|                NULL|Benzinga Newsdesk|2025-11-25 08:11:38|2025-11-25 08:11:38|https://www.benzi...|                   A|benzinga|
# |49056466|Barclays Maintain...|                NULL|Benzinga Newsdesk|2025-11-25 07:44:01|2025-11-25 07:44:02|https://www.benzi...|                   A|benzinga|
# |49054073|Baird Maintains O...|                NULL|Benzinga Newsdesk|2025-11-25 06:15:53|2025-11-25 06:15:54|https://www.benzi...|                   A|benzinga|
# |49052646|B of A Securities...|                NULL|Benzinga Newsdesk|2025-11-25 05:07:46|2025-11-25 05:07:47|https://www.benzi...|                   A|benzinga|
# |49044977|Agilent Technolog...|                NULL|Benzinga Newsdesk|2025-11-24 14:14:29|2025-11-24 14:14:29|https://www.benzi...|                   A|benzinga|
# |49044957|Agilent Technolog...|                NULL|Benzinga Newsdesk|2025-11-24 14:14:01|2025-11-24 14:14:01|https://www.benzi...|                   A|benzinga|
# |49044945|Agilent Technolog...|                NULL|Benzinga Newsdesk|2025-11-24 14:13:08|2025-11-24 14:13:09|https://www.benzi...|                   A|benzinga|
# |49042315|Top Stocks with E...|Here&#39;s a look...|   Erica Kollmann|2025-11-24 12:58:20|2025-11-24 12:58:20|https://www.benzi...|A,BABA,BBY,CLSK,D...|benzinga|
# |49038524|Live On CNBC, Jos...|                NULL|Benzinga Newsdesk|2025-11-24 10:50:05|2025-11-24 10:50:05|https://www.benzi...|               A,TMO|benzinga|
# +--------+--------------------+--------------------+-----------------+-------------------+-------------------+--------------------+--------------------+--------+
# only showing top 20 rows

# %%
stocks.show()
# Out:
# +------+-------------------+------+-------+--------+------+---------+-----------+----------+-----+
# |symbol|          timestamp|  open|   high|     low| close|   volume|trade_count|      vwap|index|
# +------+-------------------+------+-------+--------+------+---------+-----------+----------+-----+
# |     A|2025-01-07 22:00:00|137.68| 137.68|  135.63| 137.0|1684573.0|    19948.0|137.068421| NULL|
# |     A|2025-01-09 22:00:00|134.75| 140.14| 134.709|137.47|1369875.0|    25383.0|137.592663| NULL|
# |     A|2025-01-12 22:00:00|137.22| 142.82|   137.0|141.95|1561959.0|    28739.0|141.776934| NULL|
# |     A|2025-01-13 22:00:00| 142.0| 145.38|  140.15|143.43|2445434.0|    36636.0|143.373405| NULL|
# |     A|2025-01-14 22:00:00|144.14|  146.5|  138.68|142.23|2328643.0|    35076.0|142.841548| NULL|
# |     A|2025-01-15 22:00:00|142.78| 145.11|  140.43|144.72|1661474.0|    25916.0|143.989713| NULL|
# |     A|2025-01-16 22:00:00|145.88| 148.46| 145.195|147.36|3210310.0|    45636.0|147.281027| NULL|
# |     A|2025-01-20 22:00:00|148.67| 153.18|  148.01|152.57|2759636.0|    42383.0| 152.14676| NULL|
# |     A|2025-01-21 22:00:00|152.83| 153.76|  151.72| 152.6|1730996.0|    27740.0|152.631508| NULL|
# |     A|2025-01-22 22:00:00|152.83|152.955|  148.18|152.45|1332235.0|    24444.0|151.813582| NULL|
# |     A|2025-01-23 22:00:00| 152.1| 152.77|  150.78|151.44|1844887.0|    26173.0|151.688721| NULL|
# |     A|2025-01-26 22:00:00|151.56| 152.22|148.7301|150.96|2229590.0|    36050.0|150.752766| NULL|
# |     A|2025-01-27 22:00:00|152.61| 153.24|  150.21|150.34|1791623.0|    30098.0|151.228995| NULL|
# |     A|2025-01-28 22:00:00|148.99|  149.9|  146.55|147.09|1583243.0|    29197.0|147.595289| NULL|
# |     A|2025-01-29 22:00:00|148.95| 152.48|  147.65|151.38|1496057.0|    26534.0|151.307038| NULL|
# |     A|2025-01-30 22:00:00|150.96| 153.84|   150.5|151.52|1886605.0|    30617.0|152.086072| NULL|
# |     A|2025-02-02 22:00:00|149.76|150.315|  147.88|148.63|1633279.0|    28041.0|149.018587| NULL|
# |     A|2025-02-03 22:00:00|148.02| 148.65|  146.27|147.04|1287477.0|    25440.0|147.120344| NULL|
# |     A|2025-02-04 22:00:00|147.89| 148.71|  146.31|147.99|1348074.0|    21077.0|147.996397| NULL|
# |     A|2025-02-05 22:00:00|147.02| 148.61|   146.2|147.64|1142978.0|    22017.0|147.658594| NULL|
# +------+-------------------+------+-------+--------+------+---------+-----------+----------+-----+
# only showing top 20 rows

# %%
feature_set = sql_step("sql/sentiment_data_prep.sql")
feature_set.show()
# Out:
# +------+----------+--------------------+--------------------------+
# |symbol| news_date|     daily_news_text|percent_daily_price_change|
# +------+----------+--------------------+--------------------------+
# |  PRGO|2025-01-06|                    |      0.004008016032064185|
# |   TNL|2025-01-06|                    |      0.005322294500295745|
# |  RPRX|2025-01-12|News Article Numb...|      0.004347826086956608|
# |  LFUS|2025-01-13|                    |      -0.01619148936170...|
# |   NSA|2025-01-13|                    |      -0.02918918918918...|
# |   USD|2025-01-14|News Article Numb...|      -0.05604253484696085|
# |   RYN|2025-01-15|                    |       0.01221374045801528|
# |   WFC|2025-01-15|News Article Numb...|       0.01447749407738871|
# |  BOKF|2025-01-21|News Article Numb...|      -0.01828510562755...|
# |    CF|2025-01-21|News Article Numb...|      0.014919011082693856|
# |  STWD|2025-01-21|                    |      -0.00104931794333...|
# |   EXP|2025-01-22|News Article Numb...|      7.253569519737258E-4|
# |   AFG|2025-01-27|News Article Numb...|      0.003945637878123571|
# |   SFD|2025-01-27|News Article Numb...|      0.037468354430379665|
# |   TOL|2025-01-27|News Article Numb...|      -0.01601449275362...|
# |   USD|2025-01-27|News Article Numb...|      -0.02771929824561...|
# |  WELL|2025-01-27|News Article Numb...|      -0.01618665694495...|
# |  ADSK|2025-01-28|News Article Numb...|      0.010267275097783498|
# |   ECL|2025-01-28|News Article Numb...|      0.021067529316619406|
# |   HPE|2025-01-28|News Article Numb...|      -0.03900226757369612|
# +------+----------+--------------------+--------------------------+
# only showing top 20 rows
